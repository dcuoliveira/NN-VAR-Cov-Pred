# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import GridSearchCV, train_test_split, KFold
from tensorflow import keras
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler

import pandas as pd
import os

# %%
def FFNN(input_shape,
         n_neurons,
         n_hidden,
         learning_rate):
    
    # neural network dynamic architecture
    model = Sequential()
    model.add(Dense(n_neurons, input_shape=(input_shape,), activation='relu'))
    for layer in range(n_hidden):
        model.add(Dense(n_neurons, activation="relu")) 
    model.add(Dense(1))

    # define stochastic gradient descent optimizer
    optimizer = SGD(lr=learning_rate)
    model.compile(loss='mse', optimizer=optimizer)
    return model

# %%
SOURCE_PATH = os.path.dirname(os.getcwd())

N_JOBS = -1  # number of jobs to run in parallel
N_SPLITS = 10  # number of splits (k) to be made within the k fold cv
N_ITER = 50  # number of parameter settings that are sampled
SEED = 2294
VERBOSE = True
INPUTS_PATH = os.path.join(SOURCE_PATH, "data", "inputs")
OUTPUTS_PATH = os.path.join(SOURCE_PATH, "data", "outputs")
DATASET_NAMES = ["betadgp_covdgp_data", "betadgp_beta2x2_data", "betadgp_data"]
TARGET_NAME = "betas_dgp"
MODEL_TAG = "ffnn"
STANDARDIZE = True
TRAIN_SIZE = 0.7 # size of training data (in %)
DIR_NAMES = os.listdir(os.path.join(INPUTS_PATH))

VALIDATION_SIZE = 0.2

# %%
# train data
train_data = pd.read_csv(os.path.join(INPUTS_PATH, DIR_NAMES[0], DATASET_NAMES[0] + ".csv"))
train_data.set_index(["Var1", "Var2"], inplace=True)
y_train = train_data[[TARGET_NAME]].to_numpy()
X_train = train_data.drop([TARGET_NAME], axis=1).to_numpy()

# test data
test_data = pd.read_csv(os.path.join(INPUTS_PATH, DIR_NAMES[0], DATASET_NAMES[0] + "_test.csv"))
test_data.set_index(["Var1", "Var2"], inplace=True)
y_test = test_data[[TARGET_NAME]].to_numpy()
X_test = test_data.drop([TARGET_NAME], axis=1).to_numpy()

# standardize if needed
if STANDARDIZE:
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, train_size=TRAIN_SIZE)

    scaler = StandardScaler()
    X_train_zscore = scaler.fit_transform(X_train)
    X_validation_zscore = scaler.transform(X_validation)
    X_test_zscore = scaler.transform(X_test)

# %%
# wrap-up dynamic FFNN
model = keras.wrappers.scikit_learn.KerasRegressor(FFNN, verbose=0)

# define the grid search parameters
param_grid = dict(
    
    batch_size=[10, 20, 40, 60, 80, 100],
    epochs=[10, 50, 100],
    input_shape=[X_train.shape[1]],
    n_hidden=range(1, 1 + 1),
    n_neurons=[10],
    learning_rate=[0.001, 0.01, 0.1, 0.2, 0.3]
                 
)

# define data splits for the cross validation
cv_splits = KFold(n_splits=N_SPLITS)

# define hyperparameter optimization
grid = GridSearchCV(estimator=model,
                    param_grid=param_grid,
                    n_jobs=N_JOBS,
                    cv=cv_splits)

# train model
grid_result = grid.fit(X_train, y_train)

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py", line 567, in run
#     self.flag_executor_shutting_down()
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py", line 756, in flag_executor_shutting_down
#     self.kill_workers()
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py", line 766, in kill_workers
#     recursive_terminate(p)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/externals/loky/backend/utils.py", line 28, in recursive_terminate
#     _recursive_terminate_without_psutil(process)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/externals/loky/backend/utils.py", line 53, in _recursive_terminate_without_psutil
#     _recursive_terminate(process.pid)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/externals/loky/backend/utils.py", line 94, in _recursive_terminate
#     stderr=None
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/subprocess.py", line 356, in check_output
#     **kwargs).stdout
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/subprocess.py", line 438, in run
#     output=stdout, stderr=stderr)
# subprocess.CalledProcessError: Command '['pgrep', '-P', '30448']' died with <Signals.SIGINT: 2>.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/parallel.py", line 933, in retrieve
#     self._output.extend(job.get(timeout=self.timeout))
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/_parallel_backends.py", line 542, in wrap_future_result
#     return future.result(timeout=timeout)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/concurrent/futures/_base.py", line 427, in result
#     self._condition.wait(timeout)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/threading.py", line 295, in wait
#     waiter.acquire()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-282311d4f27c>", line 26, in <module>
#     grid_result = grid.fit(X_train, y_train)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/sklearn/model_selection/_search.py", line 687, in fit
#     self._run_search(evaluate_candidates)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/sklearn/model_selection/_search.py", line 1148, in _run_search
#     evaluate_candidates(ParameterGrid(self.param_grid))
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/sklearn/model_selection/_search.py", line 666, in evaluate_candidates
#     cv.split(X, y, groups)))
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/parallel.py", line 1054, in __call__
#     self.retrieve()
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/parallel.py", line 955, in retrieve
#     backend.abort_everything(ensure_ready=ensure_ready)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/_parallel_backends.py", line 561, in abort_everything
#     self._workers.terminate(kill_workers=True)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/executor.py", line 74, in terminate
#     self.shutdown(kill_workers=kill_workers)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py", line 1171, in shutdown
#     executor_manager_thread.join()
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/tensorflow_core/_api/v2/compat/__init__.py", line 23, in <module>
#     from . import v1
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/tensorflow_core/_api/v2/compat/v1/__init__.py", line 28, in <module>
#     from . import app
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 951, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 894, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1157, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1129, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1261, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1231, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 556, in spec_from_file_location
#   File "<frozen importlib._bootstrap>", line 371, in __init__
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/parallel.py", line 933, in retrieve
#     self._output.extend(job.get(timeout=self.timeout))
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/_parallel_backends.py", line 542, in wrap_future_result
#     return future.result(timeout=timeout)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/concurrent/futures/_base.py", line 427, in result
#     self._condition.wait(timeout)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/threading.py", line 295, in wait
#     waiter.acquire()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-282311d4f27c>", line 26, in <module>
#     grid_result = grid.fit(X_train, y_train)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/sklearn/model_selection/_search.py", line 687, in fit
#     self._run_search(evaluate_candidates)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/sklearn/model_selection/_search.py", line 1148, in _run_search
#     evaluate_candidates(ParameterGrid(self.param_grid))
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/sklearn/model_selection/_search.py", line 666, in evaluate_candidates
#     cv.split(X, y, groups)))
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/parallel.py", line 1054, in __call__
#     self.retrieve()
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/parallel.py", line 955, in retrieve
#     backend.abort_everything(ensure_ready=ensure_ready)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/_parallel_backends.py", line 561, in abort_everything
#     self._workers.terminate(kill_workers=True)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/executor.py", line 74, in terminate
#     self.shutdown(kill_workers=kill_workers)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py", line 1171, in shutdown
#     executor_manager_thread.join()
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/inspect.py", line 742, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/posixpath.py", line 395, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/posixpath.py", line 429, in _joinrealpath
#     if not islink(newpath):
#   File "/Users/danieloliveira/opt/anaconda3/envs/dcuoliveira/lib/python3.6/posixpath.py", line 171, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/parallel.py in retrieve(self)
#     932                 if getattr(self._backend, 'supports_timeout', False):
# --> 933                     self._output.extend(job.get(timeout=self.timeout))
#     934                 else:
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/concurrent/futures/_base.py in result(self, timeout)
#     426
# --> 427             self._condition.wait(timeout)
#     428
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/threading.py in wait(self, timeout)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-5-282311d4f27c> in <module>
#      25 # train model
# ---> 26 grid_result = grid.fit(X_train, y_train)
#      27
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     686
# --> 687             self._run_search(evaluate_candidates)
#     688
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1147         """Search all candidates in param_grid"""
# -> 1148         evaluate_candidates(ParameterGrid(self.param_grid))
#    1149
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     665                                in product(candidate_params,
# --> 666                                           cv.split(X, y, groups)))
#     667
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1053             with self._backend.retrieval_context():
# -> 1054                 self.retrieve()
#    1055             # Make sure that we get a last message telling us we are done
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/parallel.py in retrieve(self)
#     954                     ensure_ready = self._managed_backend
# --> 955                     backend.abort_everything(ensure_ready=ensure_ready)
#     956                 raise
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/_parallel_backends.py in abort_everything(self, ensure_ready)
#     560         """
# --> 561         self._workers.terminate(kill_workers=True)
#     562         self._workers = None
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/executor.py in terminate(self, kill_workers)
#      73     def terminate(self, kill_workers=False):
# ---> 74         self.shutdown(kill_workers=kill_workers)
#      75         if kill_workers:
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py in shutdown(self, wait, kill_workers)
#    1170         if executor_manager_thread is not None and wait:
# -> 1171             executor_manager_thread.join()
#    1172
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/threading.py in join(self, timeout)
#    1055         if timeout is None:
# -> 1056             self._wait_for_tstate_lock()
#    1057         else:
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1071             assert self._is_stopped
# -> 1072         elif lock.acquire(block, timeout):
#    1073             lock.release()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2043                         # in the engines. This should return a list of strings.
# -> 2044                         stb = value._render_traceback_()
#    2045                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3262                         asy = compare(code)
# -> 3263                     if (await self.run_code(code, result,  async_=asy)):
#    3264                         return True
#
#     [... skipping hidden 1 frame]
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2046                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2047                                             value, tb, tb_offset=tb_offset)
#    2048
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1435         return FormattedTB.structured_traceback(
# -> 1436             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1437
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1335             return VerboseTB.structured_traceback(
# -> 1336                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1337             )
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1192         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1193                                                                tb_offset)
#    1194
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1149
# -> 1150         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1151
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2043                         # in the engines. This should return a list of strings.
# -> 2044                         stb = value._render_traceback_()
#    2045                     except Exception:
#
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/async_helpers.py in _pseudo_sync_runner(coro)
#      66     """
#      67     try:
# ---> 68         coro.send(None)
#      69     except StopIteration as exc:
#      70         return exc.value
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_async(self, raw_cell, store_history, silent, shell_futures)
#    3070
#    3071                 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# -> 3072                        interactivity=interactivity, compiler=compiler, result=result)
#    3073
#    3074                 self.last_execution_succeeded = not has_raised
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3280             if result:
#    3281                 result.error_before_exec = sys.exc_info()[1]
# -> 3282             self.showtraceback()
#    3283             return True
#    3284
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2045                     except Exception:
#    2046                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2047                                             value, tb, tb_offset=tb_offset)
#    2048
#    2049                     self._showtraceback(etype, value, stb)
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1434             self.tb = tb
#    1435         return FormattedTB.structured_traceback(
# -> 1436             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1437
#    1438
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1334             # Verbose modes need a full traceback
#    1335             return VerboseTB.structured_traceback(
# -> 1336                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1337             )
#    1338         elif mode == 'Minimal':
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1209         while evalue:
#    1210             formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
# -> 1211                                                                      chained_exceptions_tb_offset)
#    1212             exception = self.get_parts_of_chained_exception(evalue)
#    1213
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1148
#    1149
# -> 1150         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1151
#    1152         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/opt/anaconda3/envs/dcuoliveira/lib/python3.6/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
# summarize results
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']

for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# -0.004261 (0.000497) with: {'batch_size': 10, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.001, 'n_hidden': 1, 'n_neurons': 10}
# -0.004158 (0.000511) with: {'batch_size': 10, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.01, 'n_hidden': 1, 'n_neurons': 10}
# -0.004173 (0.000470) with: {'batch_size': 10, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.1, 'n_hidden': 1, 'n_neurons': 10}
# -0.004427 (0.000901) with: {'batch_size': 10, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.2, 'n_hidden': 1, 'n_neurons': 10}
# -0.004295 (0.000595) with: {'batch_size': 10, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.3, 'n_hidden': 1, 'n_neurons': 10}
# -0.004162 (0.000474) with: {'batch_size': 10, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.001, 'n_hidden': 1, 'n_neurons': 10}
# -0.004162 (0.000508) with: {'batch_size': 10, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.01, 'n_hidden': 1, 'n_neurons': 10}
# -0.004204 (0.000498) with: {'batch_size': 10, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.1, 'n_hidden': 1, 'n_neurons': 10}
# -0.004341 (0.000571) with: {'batch_size': 10, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.2, 'n_hidden': 1, 'n_neurons': 10}
# -0.004742 (0.001418) with: {'batch_size': 10, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.3, 'n_hidden': 1, 'n_neurons': 10}
# -0.004176 (0.000531) with: {'batch_size': 10, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.001, 'n_hidden': 1, 'n_neurons': 10}
# -0.004159 (0.000515) with: {'batch_size': 10, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.01, 'n_hidden': 1, 'n_neurons': 10}
# -0.004193 (0.000524) with: {'batch_size': 10, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.1, 'n_hidden': 1, 'n_neurons': 10}
# -0.004340 (0.000541) with: {'batch_size': 10, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.2, 'n_hidden': 1, 'n_neurons': 10}
# -0.004280 (0.000625) with: {'batch_size': 10, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.3, 'n_hidden': 1, 'n_neurons': 10}
# -0.004373 (0.000677) with: {'batch_size': 20, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.001, 'n_hidden': 1, 'n_neurons': 10}
# -0.004165 (0.000594) with: {'batch_size': 20, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.01, 'n_hidden': 1, 'n_neurons': 10}
# -0.004173 (0.000521) with: {'batch_size': 20, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.1, 'n_hidden': 1, 'n_neurons': 10}
# -0.004240 (0.000526) with: {'batch_size': 20, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.2, 'n_hidden': 1, 'n_neurons': 10}
# -0.004251 (0.000536) with: {'batch_size': 20, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.3, 'n_hidden': 1, 'n_neurons': 10}
# -0.004207 (0.000548) with: {'batch_size': 20, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.001, 'n_hidden': 1, 'n_neurons': 10}
# -0.004160 (0.000503) with: {'batch_size': 20, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.01, 'n_hidden': 1, 'n_neurons': 10}
# -0.004164 (0.000499) with: {'batch_size': 20, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.1, 'n_hidden': 1, 'n_neurons': 10}
# -0.004239 (0.000627) with: {'batch_size': 20, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.2, 'n_hidden': 1, 'n_neurons': 10}
# -0.004314 (0.000468) with: {'batch_size': 20, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.3, 'n_hidden': 1, 'n_neurons': 10}
# -0.004213 (0.000611) with: {'batch_size': 20, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.001, 'n_hidden': 1, 'n_neurons': 10}
# -0.004155 (0.000513) with: {'batch_size': 20, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.01, 'n_hidden': 1, 'n_neurons': 10}
# -0.004177 (0.000505) with: {'batch_size': 20, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.1, 'n_hidden': 1, 'n_neurons': 10}
# -0.004224 (0.000583) with: {'batch_size': 20, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.2, 'n_hidden': 1, 'n_neurons': 10}
# -0.004343 (0.000530) with: {'batch_size': 20, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.3, 'n_hidden': 1, 'n_neurons': 10}
# -0.004577 (0.000571) with: {'batch_size': 40, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.001, 'n_hidden': 1, 'n_neurons': 10}
# -0.004123 (0.000484) with: {'batch_size': 40, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.01, 'n_hidden': 1, 'n_neurons': 10}
# -0.004159 (0.000507) with: {'batch_size': 40, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.1, 'n_hidden': 1, 'n_neurons': 10}
# -0.004314 (0.000597) with: {'batch_size': 40, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.2, 'n_hidden': 1, 'n_neurons': 10}
# -0.004282 (0.000569) with: {'batch_size': 40, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.3, 'n_hidden': 1, 'n_neurons': 10}
# -0.004268 (0.000566) with: {'batch_size': 40, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.001, 'n_hidden': 1, 'n_neurons': 10}
# -0.004139 (0.000515) with: {'batch_size': 40, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.01, 'n_hidden': 1, 'n_neurons': 10}
# -0.004164 (0.000514) with: {'batch_size': 40, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.1, 'n_hidden': 1, 'n_neurons': 10}
# -0.004242 (0.000570) with: {'batch_size': 40, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.2, 'n_hidden': 1, 'n_neurons': 10}
# -0.004289 (0.000572) with: {'batch_size': 40, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.3, 'n_hidden': 1, 'n_neurons': 10}
# -0.004228 (0.000545) with: {'batch_size': 40, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.001, 'n_hidden': 1, 'n_neurons': 10}
# -0.004159 (0.000514) with: {'batch_size': 40, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.01, 'n_hidden': 1, 'n_neurons': 10}
# -0.004167 (0.000514) with: {'batch_size': 40, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.1, 'n_hidden': 1, 'n_neurons': 10}
# -0.004213 (0.000483) with: {'batch_size': 40, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.2, 'n_hidden': 1, 'n_neurons': 10}
# -0.004202 (0.000546) with: {'batch_size': 40, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.3, 'n_hidden': 1, 'n_neurons': 10}
# -0.004339 (0.000723) with: {'batch_size': 60, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.001, 'n_hidden': 1, 'n_neurons': 10}
# -0.004250 (0.000515) with: {'batch_size': 60, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.01, 'n_hidden': 1, 'n_neurons': 10}
# -0.004180 (0.000525) with: {'batch_size': 60, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.1, 'n_hidden': 1, 'n_neurons': 10}
# -0.004168 (0.000524) with: {'batch_size': 60, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.2, 'n_hidden': 1, 'n_neurons': 10}
# -0.004216 (0.000510) with: {'batch_size': 60, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.3, 'n_hidden': 1, 'n_neurons': 10}
# -0.004520 (0.000579) with: {'batch_size': 60, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.001, 'n_hidden': 1, 'n_neurons': 10}
# -0.004160 (0.000510) with: {'batch_size': 60, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.01, 'n_hidden': 1, 'n_neurons': 10}
# -0.004177 (0.000525) with: {'batch_size': 60, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.1, 'n_hidden': 1, 'n_neurons': 10}
# -0.004208 (0.000481) with: {'batch_size': 60, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.2, 'n_hidden': 1, 'n_neurons': 10}
# -0.004169 (0.000528) with: {'batch_size': 60, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.3, 'n_hidden': 1, 'n_neurons': 10}
# -0.004184 (0.000454) with: {'batch_size': 60, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.001, 'n_hidden': 1, 'n_neurons': 10}
# -0.004161 (0.000529) with: {'batch_size': 60, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.01, 'n_hidden': 1, 'n_neurons': 10}
# -0.004182 (0.000514) with: {'batch_size': 60, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.1, 'n_hidden': 1, 'n_neurons': 10}
# -0.004240 (0.000542) with: {'batch_size': 60, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.2, 'n_hidden': 1, 'n_neurons': 10}
# -0.004234 (0.000512) with: {'batch_size': 60, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.3, 'n_hidden': 1, 'n_neurons': 10}
# -0.004692 (0.001355) with: {'batch_size': 80, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.001, 'n_hidden': 1, 'n_neurons': 10}
# -0.004302 (0.000568) with: {'batch_size': 80, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.01, 'n_hidden': 1, 'n_neurons': 10}
# -0.004171 (0.000528) with: {'batch_size': 80, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.1, 'n_hidden': 1, 'n_neurons': 10}
# -0.004298 (0.000536) with: {'batch_size': 80, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.2, 'n_hidden': 1, 'n_neurons': 10}
# -0.004373 (0.000533) with: {'batch_size': 80, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.3, 'n_hidden': 1, 'n_neurons': 10}
# -0.004396 (0.000507) with: {'batch_size': 80, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.001, 'n_hidden': 1, 'n_neurons': 10}
# -0.004155 (0.000485) with: {'batch_size': 80, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.01, 'n_hidden': 1, 'n_neurons': 10}
# -0.004179 (0.000510) with: {'batch_size': 80, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.1, 'n_hidden': 1, 'n_neurons': 10}
# -0.004226 (0.000497) with: {'batch_size': 80, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.2, 'n_hidden': 1, 'n_neurons': 10}
# -0.004212 (0.000549) with: {'batch_size': 80, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.3, 'n_hidden': 1, 'n_neurons': 10}
# -0.004304 (0.000476) with: {'batch_size': 80, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.001, 'n_hidden': 1, 'n_neurons': 10}
# -0.004147 (0.000497) with: {'batch_size': 80, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.01, 'n_hidden': 1, 'n_neurons': 10}
# -0.004188 (0.000510) with: {'batch_size': 80, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.1, 'n_hidden': 1, 'n_neurons': 10}
# -0.004316 (0.000431) with: {'batch_size': 80, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.2, 'n_hidden': 1, 'n_neurons': 10}
# -0.004278 (0.000476) with: {'batch_size': 80, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.3, 'n_hidden': 1, 'n_neurons': 10}
# -0.004413 (0.000584) with: {'batch_size': 100, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.001, 'n_hidden': 1, 'n_neurons': 10}
# -0.004388 (0.000590) with: {'batch_size': 100, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.01, 'n_hidden': 1, 'n_neurons': 10}
# -0.004163 (0.000503) with: {'batch_size': 100, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.1, 'n_hidden': 1, 'n_neurons': 10}
# -0.004165 (0.000515) with: {'batch_size': 100, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.2, 'n_hidden': 1, 'n_neurons': 10}
# -0.004176 (0.000515) with: {'batch_size': 100, 'epochs': 10, 'input_shape': 1, 'learning_rate': 0.3, 'n_hidden': 1, 'n_neurons': 10}
# -0.004285 (0.000627) with: {'batch_size': 100, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.001, 'n_hidden': 1, 'n_neurons': 10}
# -0.004143 (0.000502) with: {'batch_size': 100, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.01, 'n_hidden': 1, 'n_neurons': 10}
# -0.004151 (0.000514) with: {'batch_size': 100, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.1, 'n_hidden': 1, 'n_neurons': 10}
# -0.004153 (0.000511) with: {'batch_size': 100, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.2, 'n_hidden': 1, 'n_neurons': 10}
# -0.004170 (0.000488) with: {'batch_size': 100, 'epochs': 50, 'input_shape': 1, 'learning_rate': 0.3, 'n_hidden': 1, 'n_neurons': 10}
# -0.004324 (0.000717) with: {'batch_size': 100, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.001, 'n_hidden': 1, 'n_neurons': 10}
# -0.004159 (0.000511) with: {'batch_size': 100, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.01, 'n_hidden': 1, 'n_neurons': 10}
# -0.004149 (0.000511) with: {'batch_size': 100, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.1, 'n_hidden': 1, 'n_neurons': 10}
# -0.004159 (0.000517) with: {'batch_size': 100, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.2, 'n_hidden': 1, 'n_neurons': 10}
# -0.004168 (0.000503) with: {'batch_size': 100, 'epochs': 100, 'input_shape': 1, 'learning_rate': 0.3, 'n_hidden': 1, 'n_neurons': 10}
